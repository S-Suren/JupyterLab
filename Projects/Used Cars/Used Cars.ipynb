# %% [markdown]
# # Table of Contents
#  <p>

# %%
import pandas as pd
import seaborn as sb

# %%
df_main = pd.read_csv('Used_Cars.csv')
df_main.loc[5,'KBB'] = 8

df_main.head(10)
# Out:
#    Year        Make              Model  Mileage  Mileage/Year   HP  MPG (C)  \
# 0  2015      Nissan  Wersa Note S Plus     7045          3523  109       31
# 1  2013   Chevrolet              Sonic    67709         16927  138       29
# 2  2015   Chevrolet              Spark    21765         10883   84       31
# 3  2015  Mitsubishi          Lancer ES    20728         10364  148       26
# 4  2013      Toyota      Prius C Three    78562         19641   99       53
# 5  2012        MINI   Cooper Hatchback    48300          9660  121       28
# 6  2015     Hyundai         Elantra SE    42428         21214  145       28
# 7  2015     Hyundai          Accent GS    36004         18002  138       27
# 8  2015        Ford    Fiesta Titanium    53143         26572  120       28
# 9  2015     Hyundai         Accent GLS    41310         20655  138       27
#
#    MPG (H)  KBB    Price
# 0       40  7.8  11234.0
# 1       40  7.8  10995.0
# 2       39  7.9  10769.0
# 3       34  6.8  11700.0
# ...

# %%
# %matplotlib inline
sb.pairplot(df_main[['Price', 'Year', 'Mileage/Year', 'KBB', 'HP', 'MPG (C)', 'MPG (H)']])
